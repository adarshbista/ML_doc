# %% [markdown]
# **Heart Failure Prediction**

# %% [markdown]
# 1) Introduction
#
#    This notebook performs a classification analysis on the Heart Failure Prediction dataset. The primary objective is to build predictive machine learning models that determine whether a patient is at risk of heart disease based on various clinical and demographic attributes.
#
# * Dataset: Heart Failure Prediction
# * Source: Kaggle – Heart Failure Prediction Dataset
# * Target Variable: HeartDisease (0 = No Heart Disease, 1 = Heart Disease)
#
# 2) Setup and Data Loading
#
#    We begin by importing the required Python libraries for data manipulation, visualization, and machine learning. The dataset is then loaded into a Pandas DataFrame, followed by an initial inspection to understand its structure, data types, and overall quality before preprocessing.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,recall_score,f1_score,precision_score
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("heart.csv")
df.sample(10)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 824   37   M           NAP        130          250          0     Normal
# 409   53   M           NAP        160            0          1        LVH
# 576   62   M           ASY        139          170          0         ST
# 6     45   F           ATA        130          237          0     Normal
# 182   52   M           ASY        140          404          0     Normal
# 11    58   M           ATA        136          164          0         ST
# 681   51   M           ASY        140          261          0        LVH
# 408   59   M           ASY        110            0          1     Normal
# 467   63   F           ATA        132            0          0     Normal
# 592   61   M           ASY        190          287          1        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 824    187              N      3.5     Down             0
# 409    122              Y      0.0     Flat             1
# 576    120              Y      3.0     Flat             1
# 6      170              N      0.0       Up             0
# 182    124              Y      2.0     Flat             1
# 11      99              Y      2.0     Flat             1
# 681    186              Y      0.0       Up             0
# 408     94              N      0.0     Flat             1
# 467    130              N      0.1       Up             0
# 592    150              Y      2.0     Down             1

# %% [markdown]
# #### Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    str
#  2   ChestPainType   918 non-null    str
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    str
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    str
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    str
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), str(5)
# memory usage: 97.6 KB

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df['ChestPainType'].value_counts()
# Out:
# ChestPainType
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: count, dtype: int64

# %%
df.select_dtypes(include='object')
# Out:
#     Sex ChestPainType RestingECG ExerciseAngina ST_Slope
# 0     M           ATA     Normal              N       Up
# 1     F           NAP     Normal              N     Flat
# 2     M           ATA         ST              N       Up
# 3     F           ASY     Normal              Y     Flat
# 4     M           NAP     Normal              N       Up
# ..   ..           ...        ...            ...      ...
# 913   M            TA     Normal              N     Flat
# 914   M           ASY     Normal              N     Flat
# 915   M           ASY     Normal              Y     Flat
# 916   F           ATA        LVH              N     Flat
# 917   M           NAP     Normal              N       Up
#
# [918 rows x 5 columns]

# %% [markdown]
# #### Encoding

# %%
df = pd.get_dummies(df,drop_first=True)
bool_colms = df.select_dtypes(include="bool").columns
df[bool_colms] = df[bool_colms].astype(int)

# %%
# df.to_csv("encoded_heart.csv",index=False)

# %%
df
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140          289          0    172      0.0             0
# 1     49        160          180          0    156      1.0             1
# 2     37        130          283          0     98      0.0             0
# 3     48        138          214          0    108      1.5             1
# 4     54        150          195          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132      1.2             1
# 914   68        144          193          1    141      3.4             1
# 915   57        130          131          0    115      1.2             1
# 916   57        130          236          0    174      0.0             1
# 917   38        138          175          0    173      0.0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0        1                  1                  0                 0
# 1        0                  0                  1                 0
# 2        1                  1                  0                 0
# 3        0                  0                  0                 0
# 4        1                  0                  1                 0
# ..     ...                ...                ...               ...
# 913      1                  0                  0                 1
# 914      1                  0                  0                 0
# 915      1                  0                  0                 0
# 916      0                  1                  0                 0
# 917      1                  0                  1                 0
#
#      RestingECG_Normal  RestingECG_ST  ExerciseAngina_Y  ST_Slope_Flat  \
# 0                    1              0                 0              0
# 1                    1              0                 0              1
# 2                    0              1                 0              0
# 3                    1              0                 1              1
# 4                    1              0                 0              0
# ..                 ...            ...               ...            ...
# 913                  1              0                 0              1
# 914                  1              0                 0              1
# 915                  1              0                 1              1
# 916                  0              0                 0              1
# 917                  1              0                 0              0
#
#      ST_Slope_Up
# 0              1
# 1              0
# 2              1
# 3              0
# 4              1
# ..           ...
# 913            0
# 914            0
# 915            0
# 916            0
# 917            1
#
# [918 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                918 non-null    int64
#  1   RestingBP          918 non-null    int64
#  2   Cholesterol        918 non-null    int64
#  3   FastingBS          918 non-null    int64
#  4   MaxHR              918 non-null    int64
#  5   Oldpeak            918 non-null    float64
#  6   HeartDisease       918 non-null    int64
#  7   Sex_M              918 non-null    int64
#  8   ChestPainType_ATA  918 non-null    int64
#  9   ChestPainType_NAP  918 non-null    int64
#  10  ChestPainType_TA   918 non-null    int64
#  11  RestingECG_Normal  918 non-null    int64
#  12  RestingECG_ST      918 non-null    int64
#  13  ExerciseAngina_Y   918 non-null    int64
#  14  ST_Slope_Flat      918 non-null    int64
#  15  ST_Slope_Up        918 non-null    int64
# dtypes: float64(1), int64(15)
# memory usage: 114.9 KB

# %% [markdown]
# #### Correlation

# %%
corr_values = df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr_values,cmap='plasma',annot=True)
plt.savefig('correlation.jpg')
plt.show()

# %%
plt.figure(figsize=(5,4))

sns.countplot(
    x='HeartDisease',
    data=df
)

plt.title("Distribution of Heart Disease Classes")
plt.xlabel("Heart Disease")
plt.ylabel("Number of Patients")
plt.show()

# %%
sns.scatterplot(
    data=df,
    x='Age',
    y='Cholesterol',
    hue='HeartDisease'
)
# Out:
# <Axes: xlabel='Age', ylabel='Cholesterol'>

# %%
feature_corr = (
    df.corr(numeric_only=True)['HeartDisease']
      .drop('HeartDisease')
      .sort_values(ascending=False)
)

plt.figure(figsize=(10, 6))
plt.bar(feature_corr.index, feature_corr.values)
plt.xticks(rotation=90)
plt.xlabel("Features")
plt.ylabel("Correlation with HeartDisease")
plt.title("Feature Correlation with HeartDisease")
plt.show()

# %%
feature_corr
# Out:
# ST_Slope_Flat        0.554134
# ExerciseAngina_Y     0.494282
# Oldpeak              0.403951
# Sex_M                0.305445
# Age                  0.282039
# FastingBS            0.267291
# RestingBP            0.107589
# RestingECG_ST        0.102527
# ChestPainType_TA    -0.054790
# RestingECG_Normal   -0.091580
# ChestPainType_NAP   -0.212964
# Cholesterol         -0.232741
# MaxHR               -0.400421
# ChestPainType_ATA   -0.401924
# ST_Slope_Up         -0.622164
# Name: HeartDisease, dtype: float64

# %%
feature_imp = abs(df.corr(numeric_only=True)['HeartDisease'].drop('HeartDisease')).sort_values(ascending=False)

# %%
feature_imp
# Out:
# ST_Slope_Up          0.622164
# ST_Slope_Flat        0.554134
# ExerciseAngina_Y     0.494282
# Oldpeak              0.403951
# ChestPainType_ATA    0.401924
# MaxHR                0.400421
# Sex_M                0.305445
# Age                  0.282039
# FastingBS            0.267291
# Cholesterol          0.232741
# ChestPainType_NAP    0.212964
# RestingBP            0.107589
# RestingECG_ST        0.102527
# RestingECG_Normal    0.091580
# ChestPainType_TA     0.054790
# Name: HeartDisease, dtype: float64

# %%
feature_imp.index.shape
# Out:
# (15,)

# %%
X = df[feature_imp.index]

# %%
y = df[['HeartDisease']]

# %%
X.shape
# Out:
# (918, 15)

# %%
y.shape
# Out:
# (918, 1)

# %% [markdown]
# #### Splitting the dataset

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,stratify=y)

# %% [markdown]
# #### Standardization

# %%
scalar = StandardScaler()
X_train_fit = scalar.fit_transform(X_train)
X_test_fit = scalar.transform(X_test)

# %% [markdown]
# ### 1) KNN model

# %%
model_KNN = KNeighborsClassifier(n_neighbors=7)

# %%
model_KNN.fit(X_train_fit,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred = model_KNN.predict(X_test_fit)

# %% [markdown]
# #### Checking the accuracy

# %%
score = {}
for i in range(3,16,2):
    model_KNN = KNeighborsClassifier(n_neighbors=i)
    model_KNN.fit(X_train_fit,y_train)
    y_pred = model_KNN.predict(X_test_fit)
    score[i]=accuracy_score(y_test,y_pred)
score
# Out:
# {3: 0.8913043478260869,
#  5: 0.8641304347826086,
#  7: 0.8641304347826086,
#  9: 0.875,
#  11: 0.8804347826086957,
#  13: 0.8804347826086957,
#  15: 0.8641304347826086}

# %%
print("Metrics for KNN for neighbour = 7")
# Out:
# Metrics for KNN for neighbour = 7

# %%
print("Accuracy")
print(accuracy_score(y_test,y_pred))
print("Confusion Matrix")
print(confusion_matrix(y_test,y_pred))
print("Precision Score")
print(precision_score(y_test,y_pred))
print("F1_Score")
print(f1_score(y_test,y_pred))
# Out:
# Accuracy
# 0.8641304347826086
# Confusion Matrix
# [[66 16]
#  [ 9 93]]
# Precision Score
# 0.8532110091743119
# F1_Score
# 0.8815165876777251

# %% [markdown]
# #### Support Vector Classfier

# %%
model_svc = SVC(C= 10, gamma= 0.01, kernel = 'rbf')
model_svc.fit(X_train_fit,y_train)
y_pred_svc = model_svc.predict(X_test_fit)

# %%
print("Accuracy")
print(accuracy_score(y_test,y_pred_svc))
print("Confusion Matrix")
print(confusion_matrix(y_test,y_pred_svc))
print("Precision Score")
print(precision_score(y_test,y_pred_svc))
print("F1_Score")
print(f1_score(y_test,y_pred_svc))
# Out:
# Accuracy
# 0.875
# Confusion Matrix
# [[67 15]
#  [ 8 94]]
# Precision Score
# 0.8623853211009175
# F1_Score
# 0.8909952606635071

# %% [markdown]
# #### Hyperparamater Tuning

# %%
from sklearn.model_selection import GridSearchCV
param_grid = [
    {
        'kernel': ['linear'],
        'C': [0.1, 1, 10, 100]
    },
    {
        'kernel': ['rbf'],
        'C': [0.1, 1, 10, 100],
        'gamma': ['scale', 0.01, 0.1, 1]
    }
]

grid = GridSearchCV(
    SVC(),
    param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid.fit(X_train_fit, y_train)

print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.873283011834871

# %% [markdown]
# #### Decision Tree Classfier

# %%
model_decision = DecisionTreeClassifier(max_depth=8,min_samples_leaf=9,max_features= "sqrt",min_samples_split=10,criterion= "entropy")

# %%
model_decision.fit(X_train,y_train)
y_pred_dec = model_decision.predict(X_test)

# %%
print("Accuracy")
print(accuracy_score(y_test,y_pred_dec))
print("Confusion Matrix")
print(confusion_matrix(y_test,y_pred_dec))
print("Precision Score")
print(precision_score(y_test,y_pred_dec))
print("F1_Score")
print(f1_score(y_test,y_pred_dec))
# Out:
# Accuracy
# 0.8804347826086957
# Confusion Matrix
# [[68 14]
#  [ 8 94]]
# Precision Score
# 0.8703703703703703
# F1_Score
# 0.8952380952380953

# %% [markdown]
# #### Performance Evaluation

# %% [markdown]
# | Model                  | Accuracy | Precision |  F1-Score |                                                           |
# | ---------------------- | -------: | --------: |  -------: | -
# | Decision Tree          |   85.32% |     81.51 |   87.78 |
# | Support Vector Machine    |   89% |     86 |   90 |
# | K-Nearest Neighbors |   88% |     86 |   89 |

# %% [markdown]
# #### Conclusion
#
# The Heart Failure Prediction dataset was used to develop and compare three classification models: Decision Tree, k-Nearest Neighbors (kNN), and Support Vector Machine (SVM). To prepare the data for machine learning, categorical variables were encoded, the dataset was divided into training and testing sets, and feature scaling was applied to SVM and kNN after the train-test split to prevent data leakage and improve model performance.
#
# The models were evaluated using Accuracy, Precision, Recall, F1-score, and the Confusion Matrix. Among the three algorithms, SVM achieved the best overall performance, obtaining the highest accuracy and F1-score.
